# %%
import numpy as np

# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
pic=cv2.imread("C:\\Users\\User\\Desktop\\mtech\\S1\Capture.JPG")

# %%
picc=plt.imshow(pic)

# %%
p = cv2.imshow('hh',pic)
